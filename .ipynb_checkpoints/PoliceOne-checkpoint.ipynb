# %%
# Dependencies and Setup
import pandas as pd
import missingno as msno
import sidetable
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests
from census import Census
from pprint import pprint
from scipy import stats
import gmaps

# Google API Key
from config import gkey
# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# File to Load (Remember to Change These)
shoot_data_to_load = "Data/fatal-police-shootings-data.csv"

# Read shootings data and store into Pandas DataFrames
shoot_data = pd.read_csv(shoot_data_to_load)
shoot_data
# Out:
#         id                    name        date   manner_of_death       armed  \
# 0        3              Tim Elliot  2015-01-02              shot         gun
# 1        4        Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5      John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8         Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9       Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                     ...         ...               ...         ...
# 5619  6148                     NaN  2020-09-05  shot and Tasered       knife
# 5620  6142                     NaN  2020-09-06              shot       knife
# 5621  6144  Refugio Reynaldo Olivo  2020-09-06              shot       knife
# 5622  6145     Verlon Billy Stiles  2020-09-06              shot       knife
# 5623  6140           Jeffrey Meyer  2020-09-07              shot         gun
#
#        age gender race            city state  signs_of_mental_illness  \
# 0     53.0      M    A         Shelton    WA                     True
# 1     47.0      M    W           Aloha    OR                    False
# 2     23.0      M    H         Wichita    KS                    False
# 3     32.0      M    W   San Francisco    CA                     True
# 4     39.0      M    H           Evans    CO                    False
# ...    ...    ...  ...             ...   ...                      ...
# 5619   NaN      M  NaN         Chicago    IL                    False
# 5620   NaN      M  NaN       Summerlin    NV                    False
# 5621  49.0      M  NaN  Virginia Beach    VA                    False
# 5622  54.0      M  NaN     Spruce Pine    NC                    False
# 5623  51.0      M    W         Altoona    IA                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 0          attack  Not fleeing        False   -123.122    47.247
# 1          attack  Not fleeing        False   -122.892    45.487
# 2           other  Not fleeing        False    -97.281    37.695
# 3          attack  Not fleeing        False   -122.422    37.763
# 4          attack  Not fleeing        False   -104.692    40.384
# ...           ...          ...          ...        ...       ...
# 5619       attack  Not fleeing         True    -87.747    41.803
# 5620       attack  Not fleeing        False        NaN       NaN
# 5621        other  Not fleeing        False    -76.083    36.831
# 5622        other          NaN        False    -82.065    35.918
# 5623        other          NaN        False    -93.498    41.661
#
#       is_geocoding_exact
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 5619                True
# 5620                True
# 5621                True
# 5622                True
# 5623                True
#
# [5624 rows x 17 columns]

# %%
# Check the columns and data type
shoot_data.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera', 'longitude', 'latitude', 'is_geocoding_exact'],
#       dtype='object')

# %%
# Dropping the name column(name not required) and id(id is the redundant data)

shoot_data=shoot_data.drop(shoot_data.columns[[0,1]],axis=1)
shoot_data
# Out:
#             date   manner_of_death       armed   age gender race  \
# 0     2015-01-02              shot         gun  53.0      M    A
# 1     2015-01-02              shot         gun  47.0      M    W
# 2     2015-01-03  shot and Tasered     unarmed  23.0      M    H
# 3     2015-01-04              shot  toy weapon  32.0      M    W
# 4     2015-01-04              shot    nail gun  39.0      M    H
# ...          ...               ...         ...   ...    ...  ...
# 5619  2020-09-05  shot and Tasered       knife   NaN      M  NaN
# 5620  2020-09-06              shot       knife   NaN      M  NaN
# 5621  2020-09-06              shot       knife  49.0      M  NaN
# 5622  2020-09-06              shot       knife  54.0      M  NaN
# 5623  2020-09-07              shot         gun  51.0      M    W
#
#                 city state  signs_of_mental_illness threat_level         flee  \
# 0            Shelton    WA                     True       attack  Not fleeing
# 1              Aloha    OR                    False       attack  Not fleeing
# 2            Wichita    KS                    False        other  Not fleeing
# 3      San Francisco    CA                     True       attack  Not fleeing
# 4              Evans    CO                    False       attack  Not fleeing
# ...              ...   ...                      ...          ...          ...
# 5619         Chicago    IL                    False       attack  Not fleeing
# 5620       Summerlin    NV                    False       attack  Not fleeing
# 5621  Virginia Beach    VA                    False        other  Not fleeing
# 5622     Spruce Pine    NC                    False        other          NaN
# 5623         Altoona    IA                    False        other          NaN
#
#       body_camera  longitude  latitude  is_geocoding_exact
# 0           False   -123.122    47.247                True
# 1           False   -122.892    45.487                True
# 2           False    -97.281    37.695                True
# 3           False   -122.422    37.763                True
# 4           False   -104.692    40.384                True
# ...           ...        ...       ...                 ...
# 5619         True    -87.747    41.803                True
# 5620        False        NaN       NaN                True
# 5621        False    -76.083    36.831                True
# 5622        False    -82.065    35.918                True
# 5623        False    -93.498    41.661                True
#
# [5624 rows x 15 columns]

# %%
#check for missing values
shoot_data.isna().sum()
# Out:
# date                         0
# manner_of_death              0
# armed                      212
# age                        252
# gender                       1
# race                       591
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       276
# body_camera                  0
# longitude                  272
# latitude                   272
# is_geocoding_exact           0
# dtype: int64

# %%
# Find columns with null values
state_wise_data_null = shoot_data.isnull().any()
state_wise_data_null
# Out:
# date                       False
# manner_of_death            False
# armed                       True
# age                         True
# gender                      True
# race                        True
# city                       False
# state                      False
# signs_of_mental_illness    False
# threat_level               False
# flee                        True
# body_camera                False
# longitude                   True
# latitude                    True
# is_geocoding_exact         False
# dtype: bool

# %%
#Checking the heatmap for missing values to confirm
msno.heatmap(shoot_data,figsize=(10,6))
plt.savefig(f"Images/HeatMap.png")
plt.show()

# %%
# Checking to see most frequently occurring value 
shoot_data.flee.value_counts()
# Out:
# Not fleeing    3524
# Car             924
# Foot            722
# Other           178
# Name: flee, dtype: int64

# %%
# Filling the NA value with the most frequently used value
shoot_data.flee.fillna('Not Fleeing',inplace=True)

# %%
#Checking the armed column
shoot_data.armed.value_counts()
# Out:
# gun                       3190
# knife                      834
# unarmed                    356
# toy weapon                 193
# undetermined               172
#                           ...
# hand torch                   1
# vehicle and machete          1
# baseball bat and knife       1
# grenade                      1
# bean-bag gun                 1
# Name: armed, Length: 95, dtype: int64

# %%
# Filling the NA value with the most frequently used value
shoot_data.armed.fillna(shoot_data.armed.value_counts().index[0],inplace=True)

# %%
# Drop the rows that have missing values in race,age and gender columns
shoot_data.dropna(axis=0,how='any',inplace=True)

# %%
#Displaying the cleaned dataframe
shoot_data
# Out:
#             date   manner_of_death       armed   age gender race  \
# 0     2015-01-02              shot         gun  53.0      M    A
# 1     2015-01-02              shot         gun  47.0      M    W
# 2     2015-01-03  shot and Tasered     unarmed  23.0      M    H
# 3     2015-01-04              shot  toy weapon  32.0      M    W
# 4     2015-01-04              shot    nail gun  39.0      M    H
# ...          ...               ...         ...   ...    ...  ...
# 5612  2020-09-03              shot         gun  48.0      M    W
# 5615  2020-09-04              shot         gun  33.0      M    B
# 5616  2020-09-04              shot         gun  38.0      M    W
# 5617  2020-09-05              shot     vehicle  22.0      M    W
# 5623  2020-09-07              shot         gun  51.0      M    W
#
#                city state  signs_of_mental_illness threat_level         flee  \
# 0           Shelton    WA                     True       attack  Not fleeing
# 1             Aloha    OR                    False       attack  Not fleeing
# 2           Wichita    KS                    False        other  Not fleeing
# 3     San Francisco    CA                     True       attack  Not fleeing
# 4             Evans    CO                    False       attack  Not fleeing
# ...             ...   ...                      ...          ...          ...
# 5612          Lacey    WA                    False        other  Not fleeing
# 5615       Syracuse    NY                    False        other  Not fleeing
# 5616        Lucerne    CA                    False       attack  Not fleeing
# 5617   Battle Creek    MI                    False       attack          Car
# 5623        Altoona    IA                    False        other  Not Fleeing
#
#       body_camera  longitude  latitude  is_geocoding_exact
# 0           False   -123.122    47.247                True
# 1           False   -122.892    45.487                True
# 2           False    -97.281    37.695                True
# 3           False   -122.422    37.763                True
# 4           False   -104.692    40.384                True
# ...           ...        ...       ...                 ...
# 5612        False   -122.823    47.036                True
# 5615         True    -76.148    43.053                True
# 5616        False   -116.832    34.438                True
# 5617        False    -85.272    42.305                True
# 5623        False    -93.498    41.661                True
#
# [4727 rows x 15 columns]

# %%
# Checking to see data type of the columns

shoot_data.dtypes
# Out:
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# longitude                  float64
# latitude                   float64
# is_geocoding_exact            bool
# dtype: object

# %%
# Changing the format of the date column datatype
shoot_data['date'] = pd.DatetimeIndex(shoot_data['date'])

shoot_data['year'] = pd.DatetimeIndex(shoot_data['date']).year

shoot_data['month'] = pd.DatetimeIndex(shoot_data['date']).month

# %%
shoot_data.head()
# Out:
#         date   manner_of_death       armed   age gender race           city  \
# 0 2015-01-02              shot         gun  53.0      M    A        Shelton
# 1 2015-01-02              shot         gun  47.0      M    W          Aloha
# 2 2015-01-03  shot and Tasered     unarmed  23.0      M    H        Wichita
# 3 2015-01-04              shot  toy weapon  32.0      M    W  San Francisco
# 4 2015-01-04              shot    nail gun  39.0      M    H          Evans
#
#   state  signs_of_mental_illness threat_level         flee  body_camera  \
# 0    WA                     True       attack  Not fleeing        False
# 1    OR                    False       attack  Not fleeing        False
# 2    KS                    False        other  Not fleeing        False
# 3    CA                     True       attack  Not fleeing        False
# 4    CO                    False       attack  Not fleeing        False
#
#    longitude  latitude  is_geocoding_exact  year  month
# 0   -123.122    47.247                True  2015      1
# 1   -122.892    45.487                True  2015      1
# 2    -97.281    37.695                True  2015      1
# 3   -122.422    37.763                True  2015      1
# 4   -104.692    40.384                True  2015      1

# %% [markdown]
# ## Total Police Shootings per State

# %%
# Checking the no of deaths in different states
summary_data = shoot_data.stb.freq(['state'],thresh=50)
summary_data
# Out:
#     state  count    percent  cumulative_count  cumulative_percent
# 0      CA    681  14.406600               681           14.406600
# 1      TX    420   8.885128              1101           23.291728
# 2      FL    324   6.854242              1425           30.145970
# 3      AZ    212   4.484874              1637           34.630844
# 4      CO    169   3.575206              1806           38.206050
# 5      GA    154   3.257880              1960           41.463931
# 6      NC    143   3.025175              2103           44.489105
# 7      OH    142   3.004019              2245           47.493125
# 8  others   2482  52.506875              4727          100.000000

# %%
plt.figure(figsize=(12,8))
plt.title("Fatal Shootings by Police in a State", fontsize=15)
sns.barplot(x = 'state',y = 'count',data=summary_data).set(xlabel = 'State',ylabel='Number of people killed by Police')
plt.savefig(f"Images/State.png")
plt.show()

# %%
# Selecting the data in major state's where the total no of deaths is higher
shoot_age_filter = shoot_data[(shoot_data.state.isin(["CA","TX","FL","AZ"]))]
shoot_age_filter
# Out:
#            date   manner_of_death         armed   age gender race  \
# 3    2015-01-04              shot    toy weapon  32.0      M    W
# 6    2015-01-05              shot           gun  22.0      M    H
# 10   2015-01-06  shot and Tasered         knife  25.0      M    W
# 11   2015-01-07              shot           gun  31.0      M    B
# 20   2015-01-09              shot           gun  33.0      M    H
# ...         ...               ...           ...   ...    ...  ...
# 5601 2020-08-29              shot           gun  44.0      M    B
# 5604 2020-08-29              shot         knife  25.0      M    H
# 5606 2020-08-31              shot  undetermined  29.0      M    B
# 5610 2020-09-01              shot           gun  50.0      M    W
# 5616 2020-09-04              shot           gun  38.0      M    W
#
#                city state  signs_of_mental_illness threat_level         flee  \
# 3     San Francisco    CA                     True       attack  Not fleeing
# 6          Chandler    AZ                    False       attack          Car
# 10         Stockton    CA                    False       attack  Not fleeing
# 11         Freeport    TX                    False       attack  Not fleeing
# 20          El Paso    TX                    False       attack  Not fleeing
# ...             ...   ...                      ...          ...          ...
# 5601     Holly Hill    FL                    False       attack  Not fleeing
# 5604        Anaheim    CA                    False        other  Not Fleeing
# 5606    Los Angeles    CA                    False       attack         Foot
# 5610     Sacramento    CA                     True       attack         Foot
# 5616        Lucerne    CA                    False       attack  Not fleeing
#
#       body_camera  longitude  latitude  is_geocoding_exact  year  month
# 3           False   -122.422    37.763                True  2015      1
# 6           False   -111.841    33.328                True  2015      1
# 10          False   -121.299    37.930                True  2015      1
# 11          False    -95.369    28.955                True  2015      1
# 20          False   -106.439    31.858                True  2015      1
# ...           ...        ...       ...                 ...   ...    ...
# 5601         True    -81.049    29.257                True  2020      8
# 5604        False   -117.879    33.840                True  2020      8
# 5606        False   -118.296    33.936                True  2020      8
# 5610         True   -121.474    38.620                True  2020      9
# 5616        False   -116.832    34.438                True  2020      9
#
# [1637 rows x 17 columns]

# %%
#Grouping data 
shoot_state = shoot_age_filter[['state','age','manner_of_death']].groupby(['state','age']).count().reset_index()

#Renaming the column 
shoot_state.rename(columns={'manner_of_death':'number_of_deaths'},inplace=True)
shoot_state
# Out:
#     state   age  number_of_deaths
# 0      AZ  17.0                 3
# 1      AZ  18.0                 1
# 2      AZ  19.0                 4
# 3      AZ  20.0                 7
# 4      AZ  21.0                 3
# ..    ...   ...               ...
# 218    TX  71.0                 1
# 219    TX  73.0                 1
# 220    TX  74.0                 1
# 221    TX  76.0                 1
# 222    TX  84.0                 1
#
# [223 rows x 3 columns]

# %%
#Dividing the age into different groups

bins =[0,10,20,30,40,50,60,70]
group_names =["0-10","11-20","21-30","31-40","41-50","51-60","61-100"]
shoot_state["age groups"] =pd.cut(shoot_state["age"], bins, labels=group_names, include_lowest=True)
shoot_state.head()
# Out:
#   state   age  number_of_deaths age groups
# 0    AZ  17.0                 3      11-20
# 1    AZ  18.0                 1      11-20
# 2    AZ  19.0                 4      11-20
# 3    AZ  20.0                 7      11-20
# 4    AZ  21.0                 3      21-30

# %%
#Plotting the graph 

plt.figure(figsize=(12,8))
plt.title("Fatal Shootings by Police across various Age Groups", fontsize=15)
ax = sns.barplot(x = shoot_state['state'],y = shoot_state['number_of_deaths'],hue=shoot_state['age groups'])
ax.set(xlabel = 'State',ylabel = 'Number of people killed by police')
plt.savefig(f"Images/Age.png")
plt.show()

# %%
plt.figure(figsize=(40,40))
plt.title("Fatal Shootings by Police across various Age Groups", fontsize=15)
ax = sns.barplot(x=shoot_state['number_of_deaths'], y=shoot_state['state'], hue=shoot_state['age groups'])
ax.set(xlabel = 'State',ylabel = 'Number of people killed by police')
plt.show()

# %% [markdown]
# ## Racial Death of People per State

# %%
#Grouping the data based on State and Race

state_race = shoot_age_filter[['state','race','armed']].groupby(['state','race']).count().reset_index()

state_race.rename(columns={'armed':'number_of_deaths'},inplace=True)
state_race
# Out:
#    state race  number_of_deaths
# 0     AZ    B                17
# 1     AZ    H                81
# 2     AZ    N                11
# 3     AZ    W               103
# 4     CA    A                27
# 5     CA    B               122
# 6     CA    H               305
# 7     CA    N                 4
# 8     CA    O                 8
# 9     CA    W               215
# 10    FL    A                 1
# 11    FL    B               109
# 12    FL    H                51
# 13    FL    O                 5
# 14    FL    W               158
# 15    TX    A                 4
# 16    TX    B                98
# 17    TX    H               140
# 18    TX    N                 1
# 19    TX    O                 3
# 20    TX    W               174

# %%
# File to Load (Remember to Change These)
census_data_to_load = "Data/csvData.csv"

# Read state population by race data and store into pandas dataframes
census_data = pd.read_csv(census_data_to_load)
census_data.head()
# Out:
#         State  WhitePerc  BlackPerc  NativePerc  AsianPerc  IslanderPerc  \
# 0     Alabama     0.6819     0.2658      0.0053     0.0133        0.0004
# 1      Alaska     0.6484     0.0327      0.1444     0.0630        0.0120
# 2     Arizona     0.7722     0.0439      0.0446     0.0329        0.0020
# 3    Arkansas     0.7700     0.1541      0.0067     0.0147        0.0027
# 4  California     0.6010     0.0579      0.0076     0.1432        0.0039
#
#    OtherRacePerc  TwoOrMoreRacesPerc
# 0         0.0144              0.0188
# 1         0.0149              0.0846
# 2         0.0679              0.0364
# 3         0.0264              0.0254
# 4         0.1383              0.0481

# %%
# Selecting all the data from states where no of shooting are more when compared to other states
census_pd_filter = census_data[(census_data.State.isin(["California","Texas","Florida","Arizona"]))]
#census_pd_filter

#Renaming the column name
census_reorder = census_pd_filter.rename(columns={'State':'state','WhitePerc':'W','BlackPerc':'B','AsianPerc':'A','NativePerc':'N','OtherRacePerc':'O'},inplace=True)

#Transposing the rows to column to get data in a proper format to draw a graph
census_reorder = pd.melt(census_pd_filter,id_vars=['state'],value_vars=['W','B','A','N','O']
                ,var_name ='race',value_name='population')

#Sorting the tranposed data 
census_reorder = census_reorder.sort_values(by='state')
census_reorder
# Out:
# C:\Users\roshi\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          state race  population
# 0      Arizona    W      0.7722
# 16     Arizona    O      0.0679
# 4      Arizona    B      0.0439
# 12     Arizona    N      0.0446
# 8      Arizona    A      0.0329
# 17  California    O      0.1383
# 13  California    N      0.0076
# 9   California    A      0.1432
# 5   California    B      0.0579
# 1   California    W      0.6010
# 6      Florida    B      0.1610
# 18     Florida    O      0.0282
# 10     Florida    A      0.0271
# 14     Florida    N      0.0028
# 2      Florida    W      0.7539
# 11       Texas    A      0.0469
# 3        Texas    W      0.7431
# 15       Texas    N      0.0049
# 7        Texas    B      0.1207
# 19       Texas    O      0.0574

# %%
# Convert population of each race to millions
census_reorder['population'] = census_reorder['population'] *328
census_reorder
# Out:
#          state race  population
# 0      Arizona    W    253.2816
# 16     Arizona    O     22.2712
# 4      Arizona    B     14.3992
# 12     Arizona    N     14.6288
# 8      Arizona    A     10.7912
# 17  California    O     45.3624
# 13  California    N      2.4928
# 9   California    A     46.9696
# 5   California    B     18.9912
# 1   California    W    197.1280
# 6      Florida    B     52.8080
# 18     Florida    O      9.2496
# 10     Florida    A      8.8888
# 14     Florida    N      0.9184
# 2      Florida    W    247.2792
# 11       Texas    A     15.3832
# 3        Texas    W    243.7368
# 15       Texas    N      1.6072
# 7        Texas    B     39.5896
# 19       Texas    O     18.8272

# %%
# Merge state_race and census_reorder dataframes

race_df = state_race[['state','race','number_of_deaths']].merge(census_reorder[['race','population']],on='race')

race_df['deaths_per_million'] = race_df['number_of_deaths']/race_df['population']
race_df.head(30)
# Out:
#    state race  number_of_deaths  population  deaths_per_million
# 0     AZ    B                17     14.3992            1.180621
# 1     AZ    B                17     18.9912            0.895151
# 2     AZ    B                17     52.8080            0.321921
# 3     AZ    B                17     39.5896            0.429406
# 4     CA    B               122     14.3992            8.472693
# 5     CA    B               122     18.9912            6.424028
# 6     CA    B               122     52.8080            2.310256
# 7     CA    B               122     39.5896            3.081617
# 8     FL    B               109     14.3992            7.569865
# 9     FL    B               109     18.9912            5.739500
# 10    FL    B               109     52.8080            2.064081
# 11    FL    B               109     39.5896            2.753248
# 12    TX    B                98     14.3992            6.805934
# 13    TX    B                98     18.9912            5.160285
# 14    TX    B                98     52.8080            1.855779
# 15    TX    B                98     39.5896            2.475398
# 16    AZ    N                11     14.6288            0.751941
# 17    AZ    N                11      2.4928            4.412709
# 18    AZ    N                11      0.9184           11.977352
# 19    AZ    N                11      1.6072            6.844201
# 20    CA    N                 4     14.6288            0.273433
# 21    CA    N                 4      2.4928            1.604621
# 22    CA    N                 4      0.9184            4.355401
# 23    CA    N                 4      1.6072            2.488800
# 24    TX    N                 1     14.6288            0.068358
# 25    TX    N                 1      2.4928            0.401155
# 26    TX    N                 1      0.9184            1.088850
# 27    TX    N                 1      1.6072            0.622200
# 28    AZ    W               103    253.2816            0.406662
# 29    AZ    W               103    197.1280            0.522503

# %%
plt.figure(figsize=(12,8))
plt.title("Fatal shooting by Police", fontsize=15)
sns.barplot(x='state',y='deaths_per_million',hue='race',data=race_df).set(xlabel='State',ylabel='Death_per_Million')
plt.savefig(f"Images/StatevsRace.png")
plt.show()

# %%
race_df = state_race[['state','race','number_of_deaths']].merge(census_reorder[['race','population']],on='race')
race_df['deaths_per_million'] = race_df['population']/race_df['number_of_deaths']
race_df.head(30)
# Out:
#    state race  number_of_deaths  population  deaths_per_million
# 0     AZ    B                17     14.3992            0.847012
# 1     AZ    B                17     18.9912            1.117129
# 2     AZ    B                17     52.8080            3.106353
# 3     AZ    B                17     39.5896            2.328800
# 4     CA    B               122     14.3992            0.118026
# 5     CA    B               122     18.9912            0.155666
# 6     CA    B               122     52.8080            0.432852
# 7     CA    B               122     39.5896            0.324505
# 8     FL    B               109     14.3992            0.132103
# 9     FL    B               109     18.9912            0.174231
# 10    FL    B               109     52.8080            0.484477
# 11    FL    B               109     39.5896            0.363207
# 12    TX    B                98     14.3992            0.146931
# 13    TX    B                98     18.9912            0.193788
# 14    TX    B                98     52.8080            0.538857
# 15    TX    B                98     39.5896            0.403976
# 16    AZ    N                11     14.6288            1.329891
# 17    AZ    N                11      2.4928            0.226618
# 18    AZ    N                11      0.9184            0.083491
# 19    AZ    N                11      1.6072            0.146109
# 20    CA    N                 4     14.6288            3.657200
# 21    CA    N                 4      2.4928            0.623200
# 22    CA    N                 4      0.9184            0.229600
# 23    CA    N                 4      1.6072            0.401800
# 24    TX    N                 1     14.6288           14.628800
# 25    TX    N                 1      2.4928            2.492800
# 26    TX    N                 1      0.9184            0.918400
# 27    TX    N                 1      1.6072            1.607200
# 28    AZ    W               103    253.2816            2.459045
# 29    AZ    W               103    197.1280            1.913864

# %% [markdown]
# ## Total Deaths of each Race in each State

# %%
# Finding the total death of every race in each state

race_df =race_df.groupby(['state','race'])[['population','deaths_per_million']].sum().reset_index()
race_df
# Out:
#    state race  population  deaths_per_million
# 0     AZ    B    125.7880            7.399294
# 1     AZ    N     19.6472            1.786109
# 2     AZ    W    941.4256            9.140054
# 3     CA    A     82.0328            3.038252
# 4     CA    B    125.7880            1.031049
# 5     CA    N     19.6472            4.911800
# 6     CA    O     95.7104           11.963800
# 7     CA    W    941.4256            4.378724
# 8     FL    A     82.0328           82.032800
# 9     FL    B    125.7880            1.154018
# 10    FL    O     95.7104           19.142080
# 11    FL    W    941.4256            5.958390
# 12    TX    A     82.0328           20.508200
# 13    TX    B    125.7880            1.283551
# 14    TX    N     19.6472           19.647200
# 15    TX    O     95.7104           31.903467
# 16    TX    W    941.4256            5.410492

# %%
#Plotting the graph

plt.figure(figsize=(12,8))
plt.title("Fatal shooting by Police", fontsize=15)
sns.barplot(x='race',y='deaths_per_million',hue='state',data=race_df).set(xlabel='Race population',ylabel='Death_per_Million')
plt.savefig(f"Images/RaceineachState.png")
plt.show()

# %%
# Perform a linear regression on year versus violent crime rate
ps_slope, ps_int, ps_r, ps_p, ps_std_err = stats.linregress(race_df['population'], race_df['deaths_per_million'])
print(f"The r-squared is: {ps_r}")
# Out:
# The r-squared is: -0.21901232733106388

# %%
# Create equation of line to calculate predicted violent crime rate
ps_fit = ps_slope * race_df['population'] + ps_int

# %%
# Plot the linear model on top of scatter plot 
pop = race_df.iloc[:,2]
deaths_per_million = race_df.iloc[:,3]
plt.scatter(pop,deaths_per_million)
plt.plot(pop,ps_fit,"--")
plt.xticks(pop, rotation=90)
plt.xlabel('Population')
plt.ylabel('Death per Million')
plt.show()

# %%
#shoot_data.head()

map_race = shoot_data[['state','armed']].groupby(['state']).count().reset_index()
#map_race = shoot_data.groupby(['state','latitude','longitude','armed'])['armed'].count()

map_race.rename(columns={'armed':'number_of_deaths'},inplace=True)
#map_race

map_race['latitude'] = shoot_data['latitude']
map_race.latitude = map_race.latitude.astype(float)

map_race['longitude'] = shoot_data['longitude']
map_race.longitude = map_race.longitude.astype(float)

map_race['city'] = shoot_data['city']
#map_race.longitude = map_race.longitude.astype(float)
map_race
# Out:
#    state  number_of_deaths  latitude  longitude               city
# 0     AK                30    47.247   -123.122            Shelton
# 1     AL                88    45.487   -122.892              Aloha
# 2     AR                59    37.695    -97.281            Wichita
# 3     AZ               212    37.763   -122.422      San Francisco
# 4     CA               681    40.384   -104.692              Evans
# 5     CO               169    35.877    -97.423            Guthrie
# 6     CT                19    33.328   -111.841           Chandler
# 7     DC                14    38.704    -97.564            Assaria
# 8     DE                10    40.809    -91.119         Burlington
# 9     FL               324    40.413    -79.991          Knoxville
# 10    GA               154    37.930   -121.299           Stockton
# 11    HI                25    28.955    -95.369           Freeport
# 12    IA                31    39.999    -82.885           Columbus
# 13    ID                36    41.582    -93.609         Des Moines
# 14    IL                98    30.022    -90.012        New Orleans
# 15    IN                88    45.859   -108.315            Huntley
# 16    KS                48    40.772   -111.872     Salt Lake City
# 17    KY                85    33.111    -92.359             Strong
# 18    LA                98    41.083   -112.083           Syracuse
# 19    MA                29    34.542    -91.966            England
# 20    MD                77    31.858   -106.439            El Paso
# 21    ME                20    39.692    -88.304             Arcola
# 22    MI                73    33.951   -118.183         South Gate
# 23    MN                58    36.185   -115.116    North Las Vegas
# 24    MO               120    35.095   -106.586        Albuquerque
# 25    MS                57    28.912    -98.542         Jourdanton
# 26    MT                26    44.958    -93.094           St. Paul
# 27    NC               143    38.317    -90.794    Franklin County
# 28    ND                10    36.783    -76.348         Chesapeake
# 29    NE                24    40.405    -74.301         Old Bridge
# 30    NH                11    29.031    -95.428       Lake Jackson
# 31    NJ                62    40.540   -111.887             Draper
# 32    NM                90    39.826    -85.991       Indianapolis
# 33    NV                86    39.726   -104.772             Aurora
# 34    NY                87    44.825    -93.358        Bloomington
# 35    OH               142    38.266   -121.997          Fairfield
# 36    OK               141    30.748    -92.441  Evangeline Parish
# 37    OR                72    32.407    -96.069             Mabank
# 38    PA                92    37.588   -122.060            Fremont
# 39    RI                 4    35.766    -95.394           Muskogee
# 40    SC                74    34.038   -118.233        Los Angeles
# 41    SD                13    32.811    -97.334         Fort Worth
# 42    TN               122    33.085   -112.042           Maricopa
# 43    TX               420    37.565    -82.921            Gunlock
# 44    UT                59    42.257    -70.932           Weymouth
# 45    VA                85    33.509   -111.909         Scottsdale
# 46    VT                 6    33.742   -116.958              Hemet
# 47    WA               122    26.559    -99.123            Chapeno
# 48    WI                85    38.665    -90.250          St. Louis
# 49    WV                36    42.908    -71.337              Derry
# 50    WY                12    31.080   -105.028      Sierra Blanca

# %%
# Store latitude and longitude in locations
locations = map_race[["latitude", "longitude"]]

# Fill NaN values and convert to float
number_of_deaths = map_race["number_of_deaths"].astype(float)

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>TotalDeaths</dt><dd>{number_of_deaths}</dd>
<dt>City</dt><dd>{city}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
shooting_info = [info_box_template.format(**row) for index, row in map_race.iterrows()]
locations = map_race[["latitude", "longitude"]]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=number_of_deaths, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
# Create symbol layer
shoot_layer = gmaps.marker_layer(
    locations,info_box_content=[info_box_template.format(**row) for index, row in  map_race.iterrows()]
)


# Add layer
fig.add_layer(heat_layer)
fig.add_layer(shoot_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
