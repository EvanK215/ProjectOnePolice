# %%
# Dependencies and Setup
import pandas as pd
import missingno as msno
import sidetable
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# File to Load (Remember to Change These)
shoot_data_to_load = "Data/shootings_wash_post.csv"

# Read shootings data and store into Pandas DataFrames
shoot_data = pd.read_csv(shoot_data_to_load)
shoot_data
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5547  6048               TK TK  2020-08-15              shot         knife
# 5548  6042        Thomas Moles  2020-08-16              shot  undetermined
# 5549  6043  Jose Manuel Castro  2020-08-16              shot         knife
# 5550  6044     Jeffrey Hubbard  2020-08-16              shot           gun
# 5551  6045               TK TK  2020-08-16              shot           gun
#
#        age gender race           city state  signs_of_mental_illness  \
# 0     53.0      M    A        Shelton    WA                     True
# 1     47.0      M    W          Aloha    OR                    False
# 2     23.0      M    H        Wichita    KS                    False
# 3     32.0      M    W  San Francisco    CA                     True
# 4     39.0      M    H          Evans    CO                    False
# ...    ...    ...  ...            ...   ...                      ...
# 5547   NaN      M  NaN         Denver    CO                    False
# 5548  35.0      M    W   Maury County    TN                    False
# 5549  27.0      M    H      Dos Palos    CA                    False
# 5550  67.0      M    W      Las Vegas    NV                     True
# 5551  30.0      M  NaN          Hemet    CA                    False
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 5547       attack  Not fleeing        False
# 5548        other        Other        False
# 5549        other  Not fleeing        False
# 5550        other  Not fleeing        False
# 5551        other          Car        False
#
# [5552 rows x 14 columns]

# %%
# Check the columns and data type
shoot_data.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
# Dropping the name column(name not required) and id(id is the redundant data)

shoot_data=shoot_data.drop(shoot_data.columns[[0,1]],axis=1)
shoot_data
# Out:
#             date   manner_of_death         armed   age gender race  \
# 0     2015-01-02              shot           gun  53.0      M    A
# 1     2015-01-02              shot           gun  47.0      M    W
# 2     2015-01-03  shot and Tasered       unarmed  23.0      M    H
# 3     2015-01-04              shot    toy weapon  32.0      M    W
# 4     2015-01-04              shot      nail gun  39.0      M    H
# ...          ...               ...           ...   ...    ...  ...
# 5547  2020-08-15              shot         knife   NaN      M  NaN
# 5548  2020-08-16              shot  undetermined  35.0      M    W
# 5549  2020-08-16              shot         knife  27.0      M    H
# 5550  2020-08-16              shot           gun  67.0      M    W
# 5551  2020-08-16              shot           gun  30.0      M  NaN
#
#                city state  signs_of_mental_illness threat_level         flee  \
# 0           Shelton    WA                     True       attack  Not fleeing
# 1             Aloha    OR                    False       attack  Not fleeing
# 2           Wichita    KS                    False        other  Not fleeing
# 3     San Francisco    CA                     True       attack  Not fleeing
# 4             Evans    CO                    False       attack  Not fleeing
# ...             ...   ...                      ...          ...          ...
# 5547         Denver    CO                    False       attack  Not fleeing
# 5548   Maury County    TN                    False        other        Other
# 5549      Dos Palos    CA                    False        other  Not fleeing
# 5550      Las Vegas    NV                     True        other  Not fleeing
# 5551          Hemet    CA                    False        other          Car
#
#       body_camera
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 5547        False
# 5548        False
# 5549        False
# 5550        False
# 5551        False
#
# [5552 rows x 12 columns]

# %%
#check for missing values
shoot_data.isna().sum()
# Out:
# date                         0
# manner_of_death              0
# armed                      213
# age                        245
# gender                       1
# race                       586
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       262
# body_camera                  0
# dtype: int64

# %%
# Find columns with null values
state_wise_data_null = shoot_data.isnull().any()
state_wise_data_null
# Out:
# date                       False
# manner_of_death            False
# armed                       True
# age                         True
# gender                      True
# race                        True
# city                       False
# state                      False
# signs_of_mental_illness    False
# threat_level               False
# flee                        True
# body_camera                False
# dtype: bool

# %%
#Checking the heatmap for missing values to confirm
msno.heatmap(shoot_data,figsize=(10,6))

# %%
# Checking to see most frequently occurring value 
shoot_data.flee.value_counts()
# Out:
# Not fleeing    3489
# Car             917
# Foot            710
# Other           174
# Name: flee, dtype: int64

# %%
# Filling the NA value with the most frequently used value
shoot_data.flee.fillna('Not Fleeing',inplace=True)

# %%
#Checking the armed column
shoot_data.armed.value_counts()
# Out:
# gun                    3146
# knife                   818
# unarmed                 355
# toy weapon              193
# undetermined            168
#                        ...
# gun and sword             1
# metal rake                1
# hand torch                1
# bean-bag gun              1
# vehicle and machete       1
# Name: armed, Length: 94, dtype: int64

# %%
# Filling the NA value with the most frequently used value
shoot_data.armed.fillna(shoot_data.armed.value_counts().index[0],inplace=True)

# %%
# Drop the rows that have missing values in race,ageand gender columns
shoot_data.dropna(axis=0,how='any',inplace=True)

# %%
#Displaying the cleaned dataframe
shoot_data
# Out:
#             date   manner_of_death         armed   age gender race  \
# 0     2015-01-02              shot           gun  53.0      M    A
# 1     2015-01-02              shot           gun  47.0      M    W
# 2     2015-01-03  shot and Tasered       unarmed  23.0      M    H
# 3     2015-01-04              shot    toy weapon  32.0      M    W
# 4     2015-01-04              shot      nail gun  39.0      M    H
# ...          ...               ...           ...   ...    ...  ...
# 5545  2020-08-15              shot           gun  32.0      M    B
# 5546  2020-08-15              shot           gun  51.0      M    W
# 5548  2020-08-16              shot  undetermined  35.0      M    W
# 5549  2020-08-16              shot         knife  27.0      M    H
# 5550  2020-08-16              shot           gun  67.0      M    W
#
#                city state  signs_of_mental_illness threat_level         flee  \
# 0           Shelton    WA                     True       attack  Not fleeing
# 1             Aloha    OR                    False       attack  Not fleeing
# 2           Wichita    KS                    False        other  Not fleeing
# 3     San Francisco    CA                     True       attack  Not fleeing
# 4             Evans    CO                    False       attack  Not fleeing
# ...             ...   ...                      ...          ...          ...
# 5545       Pasadena    CA                    False        other         Foot
# 5546  Marion County    FL                    False       attack  Not Fleeing
# 5548   Maury County    TN                    False        other        Other
# 5549      Dos Palos    CA                    False        other  Not fleeing
# 5550      Las Vegas    NV                     True        other  Not fleeing
#
#       body_camera
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 5545        False
# 5546        False
# 5548        False
# 5549        False
# 5550        False
#
# [4878 rows x 12 columns]

# %%
# Checking to see data type of the columns

shoot_data.dtypes
# Out:
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# dtype: object

# %%
# Changing the format of the date column datatype
shoot_data['date'] = pd.DatetimeIndex(shoot_data['date'])

shoot_data['year'] = pd.DatetimeIndex(shoot_data['date']).year

shoot_data['month'] = pd.DatetimeIndex(shoot_data['date']).month

# %%
shoot_data.head()
# Out:
#         date   manner_of_death       armed   age gender race           city  \
# 0 2015-01-02              shot         gun  53.0      M    A        Shelton
# 1 2015-01-02              shot         gun  47.0      M    W          Aloha
# 2 2015-01-03  shot and Tasered     unarmed  23.0      M    H        Wichita
# 3 2015-01-04              shot  toy weapon  32.0      M    W  San Francisco
# 4 2015-01-04              shot    nail gun  39.0      M    H          Evans
#
#   state  signs_of_mental_illness threat_level         flee  body_camera  year  \
# 0    WA                     True       attack  Not fleeing        False  2015
# 1    OR                    False       attack  Not fleeing        False  2015
# 2    KS                    False        other  Not fleeing        False  2015
# 3    CA                     True       attack  Not fleeing        False  2015
# 4    CO                    False       attack  Not fleeing        False  2015
#
#    month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# Checking the no of deaths in different states
summary_data = shoot_data.stb.freq(['state'],thresh=50)
summary_data
# Out:
#     state  count    percent  cumulative_count  cumulative_percent
# 0      CA    690  14.145141               690           14.145141
# 1      TX    428   8.774088              1118           22.919229
# 2      FL    329   6.744567              1447           29.663797
# 3      AZ    222   4.551046              1669           34.214842
# 4      CO    170   3.485035              1839           37.699877
# 5      GA    159   3.259533              1998           40.959410
# 6      OK    148   3.034030              2146           43.993440
# 7      OH    147   3.013530              2293           47.006970
# 8      NC    145   2.972530              2438           49.979500
# 9  others   2440  50.020500              4878          100.000000

# %%
plt.figure(figsize=(12,8))
plt.title("Fatal Shootings by Police in a State", fontsize=15)
sns.barplot(x = summary_data['state'],y = summary_data['count'])

# %%
# Selecting the data in major state's where the total no of deaths is higher
shoot_age_filter = shoot_data[(shoot_data.state.isin(["CA","TX","FL","AZ"]))]
shoot_age_filter
# Out:
#            date   manner_of_death       armed   age gender race  \
# 3    2015-01-04              shot  toy weapon  32.0      M    W
# 6    2015-01-05              shot         gun  22.0      M    H
# 10   2015-01-06  shot and Tasered       knife  25.0      M    W
# 11   2015-01-07              shot         gun  31.0      M    B
# 20   2015-01-09              shot         gun  33.0      M    H
# ...         ...               ...         ...   ...    ...  ...
# 5521 2020-08-05              shot         gun  29.0      M    H
# 5526 2020-08-07              shot         gun  22.0      M    B
# 5545 2020-08-15              shot         gun  32.0      M    B
# 5546 2020-08-15              shot         gun  51.0      M    W
# 5549 2020-08-16              shot       knife  27.0      M    H
#
#                city state  signs_of_mental_illness threat_level         flee  \
# 3     San Francisco    CA                     True       attack  Not fleeing
# 6          Chandler    AZ                    False       attack          Car
# 10         Stockton    CA                    False       attack  Not fleeing
# 11         Freeport    TX                    False       attack  Not fleeing
# 20          El Paso    TX                    False       attack  Not fleeing
# ...             ...   ...                      ...          ...          ...
# 5521     San Angelo    TX                    False       attack        Other
# 5526        Orlando    FL                    False        other         Foot
# 5545       Pasadena    CA                    False        other         Foot
# 5546  Marion County    FL                    False       attack  Not Fleeing
# 5549      Dos Palos    CA                    False        other  Not fleeing
#
#       body_camera  year  month
# 3           False  2015      1
# 6           False  2015      1
# 10          False  2015      1
# 11          False  2015      1
# 20          False  2015      1
# ...           ...   ...    ...
# 5521        False  2020      8
# 5526         True  2020      8
# 5545        False  2020      8
# 5546        False  2020      8
# 5549        False  2020      8
#
# [1669 rows x 14 columns]

# %%
#Grouping data 
shoot_state = shoot_age_filter[['state','age','manner_of_death']].groupby(['state','age']).count().reset_index()


shoot_state.rename(columns={'manner_of_death':'number_of_deaths'},inplace=True)
shoot_state
# Out:
#     state   age  number_of_deaths
# 0      AZ  14.0                 1
# 1      AZ  17.0                 3
# 2      AZ  18.0                 1
# 3      AZ  19.0                 4
# 4      AZ  20.0                 7
# ..    ...   ...               ...
# 220    TX  71.0                 1
# 221    TX  73.0                 1
# 222    TX  74.0                 1
# 223    TX  76.0                 1
# 224    TX  84.0                 1
#
# [225 rows x 3 columns]

# %%
bins =[0,18,25,50,60,80,100]
group_names =["0-18","19-25","26-50","51-60","61-80","80-100"]
shoot_state["age groups"] =pd.cut(shoot_state["age"], bins, labels=group_names, include_lowest=True)
shoot_state
# Out:
#     state   age  number_of_deaths age groups
# 0      AZ  14.0                 1       0-18
# 1      AZ  17.0                 3       0-18
# 2      AZ  18.0                 1       0-18
# 3      AZ  19.0                 4      19-25
# 4      AZ  20.0                 7      19-25
# ..    ...   ...               ...        ...
# 220    TX  71.0                 1      61-80
# 221    TX  73.0                 1      61-80
# 222    TX  74.0                 1      61-80
# 223    TX  76.0                 1      61-80
# 224    TX  84.0                 1     80-100
#
# [225 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))
plt.title("Fatal Shootings by Police across various Age Groups", fontsize=15)
ax = sns.barplot(x = shoot_state['state'],y = shoot_state['number_of_deaths'],hue=shoot_state['age groups'])
ax.set(xlabel = 'State',ylabel = 'Total no of Death')
plt.show()
